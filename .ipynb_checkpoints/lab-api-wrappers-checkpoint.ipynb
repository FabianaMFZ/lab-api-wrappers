# %%
import requests
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="fa2ce880ceab4755a6380df2d51348dc",
                                                           client_secret="0084be953d5c4cff858aae07563e8cb8"))
sp

# %% [markdown]
# ### Nirvana

# %%
results = sp.search(q = 'Nirvana', limit = 50)
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Nirvana&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#        'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#        'id': '6olE6TJLqED3rqDCT0FyPh',
#        'name': 'Nirvana',
#        'type': 'artist',
#        'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2guirTSEqLizK7j9i1MTTZ'},
#      'href': 'https://api.spotify.com/v1/albums/2guirTSEqLizK7j9i1MTTZ',
#      'id': '2guirTSEqLizK7j9i1MTTZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e175a19e530c898d167d39bf',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e175a19e530c898d167d39bf',
# ...

# %%
results['tracks']['items']
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#      'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#      'id': '6olE6TJLqED3rqDCT0FyPh',
#      'name': 'Nirvana',
#      'type': 'artist',
#      'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#    'available_markets': ['CA', 'MX', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2guirTSEqLizK7j9i1MTTZ'},
#    'href': 'https://api.spotify.com/v1/albums/2guirTSEqLizK7j9i1MTTZ',
#    'id': '2guirTSEqLizK7j9i1MTTZ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273e175a19e530c898d167d39bf',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02e175a19e530c898d167d39bf',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851e175a19e530c898d167d39bf',
# ...

# %%
artist_name = "Nirvana"
results = sp.search(q=f'artist:{artist_name}', type='artist')
artist_id = results['artists']['items'][0]['id']

# %%
top_tracks = sp.artist_top_tracks(artist_id)
top_tracks
# Out:
# {'tracks': [{'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#       'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#       'id': '6olE6TJLqED3rqDCT0FyPh',
#       'name': 'Nirvana',
#       'type': 'artist',
#       'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2guirTSEqLizK7j9i1MTTZ'},
#     'href': 'https://api.spotify.com/v1/albums/2guirTSEqLizK7j9i1MTTZ',
#     'id': '2guirTSEqLizK7j9i1MTTZ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e175a19e530c898d167d39bf',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e175a19e530c898d167d39bf',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e175a19e530c898d167d39bf',
#       'width': 64}],
# ...

# %%
for idx, track in enumerate(top_tracks['tracks'][:10]):
    print(f"{idx + 1}. {track['name']} - {track['popularity']}")
# Out:
# 1. Smells Like Teen Spirit - 77
# 2. Come As You Are - 76
# 3. Heart-Shaped Box - 79
# 4. About A Girl - 79
# 5. Lithium - 70
# 6. Dumb - 75
# 7. Something In The Way - 68
# 8. The Man Who Sold The World - Live - 74
# 9. In Bloom - 68
# 10. All Apologies - 72

# %%
for idx, track in enumerate(top_tracks['tracks'][:10]):
    print(f"Track {idx + 1}:")
    print(f"Name: {track['name']}")
    print(f"Album: {track['album']['name']}")
    print(f"Release Date: {track['album']['release_date']}")
    print(f"Popularity: {track['popularity']}")
    print(f"Preview URL: {track['preview_url']}")
    print(f"Spotify URL: {track['external_urls']['spotify']}")
    print("-" * 40)
# Out:
# Track 1:
# Name: Smells Like Teen Spirit
# Album: Nevermind (Remastered)
# Release Date: 1991-09-26
# Popularity: 77
# Preview URL: None
# Spotify URL: https://open.spotify.com/track/5ghIJDpPoe3CfHMGu71E6T
# ----------------------------------------
# Track 2:
# Name: Come As You Are
# Album: Nevermind (Remastered)
# Release Date: 1991-09-26
# Popularity: 76
# Preview URL: None
# Spotify URL: https://open.spotify.com/track/4P5KoWXOxwuobLmHXLMobV
# ----------------------------------------
# Track 3:
# Name: Heart-Shaped Box
# Album: In Utero (Deluxe Edition)
# Release Date: 1993-09-21
# Popularity: 79
# Preview URL: None
# Spotify URL: https://open.spotify.com/track/11LmqTE2naFULdEP94AUBa
# ----------------------------------------
# Track 4:
# Name: About A Girl
# Album: Bleach
# Release Date: 1989-06-01
# Popularity: 79
# Preview URL: https://p.scdn.co/mp3-preview/21a44c2cce969651f84906817a016d894508eb50?cid=fa2ce880ceab4755a6380df2d51348dc
# ...

# %%
nirvana = pd.DataFrame(top_tracks['tracks'])
# Normalize the 'album' column which contains dictionaries
nirvana_albums = pd.json_normalize(nirvana['album'])

# Extract the 'name' column from the normalized dataframe
nirvana_album_names = nirvana_albums[['name']]

nirvana_album_names_df = pd.DataFrame(nirvana_album_names)

nirvana_album_names_df = nirvana_album_names_df.rename(columns={'name': 'album_name'})
nirvana_album_names_df
# Out:
#                   album_name
# 0     Nevermind (Remastered)
# 1     Nevermind (Remastered)
# 2  In Utero (Deluxe Edition)
# 3                     Bleach
# 4     Nevermind (Remastered)
# 5                   In Utero
# 6     Nevermind (Remastered)
# 7  MTV Unplugged In New York
# 8     Nevermind (Remastered)
# 9                   In Utero

# %%
nirvana_top = pd.concat([nirvana, nirvana_album_names_df], axis = 1)
nirvana_top

nirvana_top = nirvana_top.rename(columns={'name': 'song_name'})

nirvana_top[['song_name', 'album_name','popularity', 'href']]
# Out:
#                            song_name                 album_name  popularity  \
# 0            Smells Like Teen Spirit     Nevermind (Remastered)          77
# 1                    Come As You Are     Nevermind (Remastered)          76
# 2                   Heart-Shaped Box  In Utero (Deluxe Edition)          79
# 3                       About A Girl                     Bleach          79
# 4                            Lithium     Nevermind (Remastered)          70
# 5                               Dumb                   In Utero          75
# 6               Something In The Way     Nevermind (Remastered)          68
# 7  The Man Who Sold The World - Live  MTV Unplugged In New York          74
# 8                           In Bloom     Nevermind (Remastered)          68
# 9                      All Apologies                   In Utero          72
#
#                                                 href
# 0  https://api.spotify.com/v1/tracks/5ghIJDpPoe3C...
# ...

# %%
import spotipy
import sys
from spotipy.oauth2 import SpotifyClientCredentials

nirvana = 'Nirvana'
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="fa2ce880ceab4755a6380df2d51348dc",
                                                           client_secret="0084be953d5c4cff858aae07563e8cb8"))

albums = sp.artist_albums(artist_id, album_type='album')

all_albums = []
while albums:
    all_albums.extend(albums['items'])
    if albums['next']:
        albums = sp.next(albums)
    else:
        albums = None


for album in all_albums:
    print(album['name'])
# Out:
# In Utero (30th Anniversary Super Deluxe)
# Nevermind (30th Anniversary Super Deluxe)
# Live And Loud
# Live At The Paramount
# Live at Reading
# From The Muddy Banks Of The Wishkah (Live)
# MTV Unplugged In New York (25th Anniversary)
# MTV Unplugged In New York
# In Utero (Super Deluxe Edition)
# In Utero (Deluxe Edition)
# In Utero
# Incesticide
# Nevermind (Super Deluxe Edition)
# Nevermind (Remastered)
# Nevermind (Deluxe Edition)
# Bleach (Deluxe Edition)
# Bleach

# %%
nirvana_albums = pd.DataFrame(all_albums)
nirvana_albums[['name', 'release_date','total_tracks', 'href']]
# Out:
#                                             name release_date  total_tracks  \
# 0       In Utero (30th Anniversary Super Deluxe)   2023-10-27            72
# 1      Nevermind (30th Anniversary Super Deluxe)   2021-11-12            75
# 2                                  Live And Loud   2019-07-26            17
# 3                          Live At The Paramount   2019-04-12            19
# 4                                Live at Reading   2009-01-01            24
# 5     From The Muddy Banks Of The Wishkah (Live)   1996-10-01            17
# 6   MTV Unplugged In New York (25th Anniversary)   1994-11-01            19
# 7                      MTV Unplugged In New York   1994-11-01            14
# 8                In Utero (Super Deluxe Edition)   1993-09-21            60
# 9                      In Utero (Deluxe Edition)   1993-09-21            43
# 10                                      In Utero   1993-09-21            12
# ...

# %% [markdown]
# ### Led Zeppelin

# %%
# how to get 30 second samples and cover art for the top 10 tracks for Led Zeppelin

lz_uri = 'spotify:artist:36QJpDe2go2KgaRleHCDTp'

spotify = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="fa2ce880ceab4755a6380df2d51348dc",
                                                           client_secret="0084be953d5c4cff858aae07563e8cb8"))

results = spotify.artist_top_tracks(lz_uri)

for track in results['tracks'][:10]:
    print('track    : ' + track['name'])
    print('audio    : ' + track['preview_url'])
    print('cover art: ' + track['album']['images'][0]['url'])
    print()
# Out:
# track    : Stairway to Heaven - Remaster
# audio    : https://p.scdn.co/mp3-preview/337c8d45ac66899bc2db9ef3ed9438fe1d035ab1?cid=fa2ce880ceab4755a6380df2d51348dc
# cover art: https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69
#
# track    : Immigrant Song - Remaster
# audio    : https://p.scdn.co/mp3-preview/f50f3416ea0807503e172ba87a92d8047d4f95da?cid=fa2ce880ceab4755a6380df2d51348dc
# cover art: https://i.scdn.co/image/ab67616d0000b27390a50cfe99a4c19ff3cbfbdb
#
# track    : Whole Lotta Love - 1990 Remaster
# audio    : https://p.scdn.co/mp3-preview/89f3dc45265602fa874c23d638538af0f2c6b56a?cid=fa2ce880ceab4755a6380df2d51348dc
# cover art: https://i.scdn.co/image/ab67616d0000b273fc4f17340773c6c3579fea0d
#
# track    : Black Dog - Remaster
# audio    : https://p.scdn.co/mp3-preview/78dd352fdbe8d2a867b72c5a71ac44ef6a462ab4?cid=fa2ce880ceab4755a6380df2d51348dc
# cover art: https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69
#
# ...

# %%
results.keys()

ld = pd.DataFrame(results['tracks'])
ld
# Out:
#                                                album  \
# 0  {'album_type': 'album', 'artists': [{'external...
# 1  {'album_type': 'album', 'artists': [{'external...
# 2  {'album_type': 'album', 'artists': [{'external...
# 3  {'album_type': 'album', 'artists': [{'external...
# 4  {'album_type': 'album', 'artists': [{'external...
# 5  {'album_type': 'album', 'artists': [{'external...
# 6  {'album_type': 'album', 'artists': [{'external...
# 7  {'album_type': 'album', 'artists': [{'external...
# 8  {'album_type': 'album', 'artists': [{'external...
# 9  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  disc_number  \
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
# 1  [{'external_urls': {'spotify': 'https://open.s...            1
# 2  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# ...

# %%
# Normalize the 'artist' column
ld_artists = pd.json_normalize(ld['artists'].explode())

ld_artists_names = ld_artists[['name']]

ld_artists_names_df = pd.DataFrame(ld_artists_names)
ld_artists_names_df = ld_artists_names_df.rename(columns={'name': 'artist'})
ld_artists_names_df
# Out:
#          artist
# 0  Led Zeppelin
# 1  Led Zeppelin
# 2  Led Zeppelin
# 3  Led Zeppelin
# 4  Led Zeppelin
# 5  Led Zeppelin
# 6  Led Zeppelin
# 7  Led Zeppelin
# 8  Led Zeppelin
# 9  Led Zeppelin

# %%
# Normalize the 'album' column
ld_albums = pd.json_normalize(ld['album'])
ld_album_names = ld_albums[['name']]

# Create a DataFrame and rename the column
ld_album_names_df = pd.DataFrame(ld_album_names)
ld_album_names_df = ld_album_names_df.rename(columns={'name': 'album_name'})
ld_album_names_df
# Out:
#                             album_name
# 0     Led Zeppelin IV (Deluxe Edition)
# 1          Led Zeppelin III (Remaster)
# 2      Led Zeppelin II (1994 Remaster)
# 3     Led Zeppelin IV (Deluxe Edition)
# 4     Led Zeppelin IV (Deluxe Edition)
# 5      Led Zeppelin II (1994 Remaster)
# 6     Led Zeppelin IV (Deluxe Edition)
# 7                         Led Zeppelin
# 8   Physical Graffiti (Deluxe Edition)
# 9  Houses of the Holy (Deluxe Edition)

# %%
# Concatenate the original DataFrame with the new DataFrames
ld_top = pd.concat([ld, ld_album_names_df, ld_artists_names_df], axis=1)

ld_top[['artist','name', 'popularity','album_name','preview_url', 'href']]
# Out:
#          artist                                  name  popularity  \
# 0  Led Zeppelin         Stairway to Heaven - Remaster          77
# 1  Led Zeppelin             Immigrant Song - Remaster          77
# 2  Led Zeppelin      Whole Lotta Love - 1990 Remaster          74
# 3  Led Zeppelin                  Black Dog - Remaster          71
# 4  Led Zeppelin              Rock and Roll - Remaster          69
# 5  Led Zeppelin             Ramble On - 1990 Remaster          68
# 6  Led Zeppelin        Going to California - Remaster          68
# 7  Led Zeppelin  Good Times Bad Times - 1993 Remaster          68
# 8  Led Zeppelin                    Kashmir - Remaster          68
# 9  Led Zeppelin               D'yer Mak'er - Remaster          64
#
#                             album_name  \
# 0     Led Zeppelin IV (Deluxe Edition)
# 1          Led Zeppelin III (Remaster)
# 2      Led Zeppelin II (1994 Remaster)
# 3     Led Zeppelin IV (Deluxe Edition)
# ...

# %% [markdown]
# ### Mix dos Anos 2000

# %%
client_id = "fa2ce880ceab4755a6380df2d51348dc"
client_secret = "0084be953d5c4cff858aae07563e8cb8"

import time

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

def getTrackIDs(user, playlist_id):
    ids = []
    playlist = sp.user_playlist(user, playlist_id)
    for item in playlist['tracks']['items']:
        track = item['track']
        ids.append(track['id'])
    return ids

# Corrected function call
user = 'spotify'
playlist_id = '37i9dQZF1EQn4jwNIohw50?si=5d578bed99d3410d'.split('?')[0]
ids = getTrackIDs(user, playlist_id)

def getTrackFeatures(track_id):
    meta = sp.track(track_id)
    features = sp.audio_features(track_id)

    # meta
    name = meta['name']
    album = meta['album']['name']
    artist = meta['album']['artists'][0]['name']
    release_date = meta['album']['release_date']
    length = meta['duration_ms']
    popularity = meta['popularity']

    # features
    acousticness = features[0]['acousticness']
    danceability = features[0]['danceability']
    energy = features[0]['energy']
    instrumentalness = features[0]['instrumentalness']
    liveness = features[0]['liveness']
    loudness = features[0]['loudness']
    speechiness = features[0]['speechiness']
    tempo = features[0]['tempo']
    time_signature = features[0]['time_signature']

    track = [name, album, artist, release_date, length, popularity, acousticness, danceability, energy, instrumentalness, liveness, loudness, speechiness, tempo, time_signature]
    return track

# loop over track ids
tracks = []
for i in range(len(ids)):
    time.sleep(0.5)
    track = getTrackFeatures(ids[i])
    tracks.append(track)

# %%
# create dataset
df = pd.DataFrame(tracks, columns=['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])
df.to_csv("spotify.csv", sep=',')
df
# Out:
#                                                  name  \
# 0                                    I Wanna Be Yours
# 1                                       The Scientist
# 2                                           Unwritten
# 3                                          Without Me
# 4                  Hips Don't Lie (feat. Wyclef Jean)
# 5                                          In the End
# 6                                              Yellow
# 7                                      Mr. Brightside
# 8                                         Mockingbird
# 9                                    Hey, Soul Sister
# 10                                  Seven Nation Army
# 11                                       Viva La Vida
# 12                                  How You Remind Me
# 13                                The Real Slim Shady
# 14                   Yeah! (feat. Lil Jon & Ludacris)
# 15                                     Feel Good Inc.
# ...

# %%
df.describe()
# Out:
#               length  popularity  acousticness  danceability     energy  \
# count      50.000000   50.000000     50.000000     50.000000  50.000000
# mean   236590.860000   84.040000      0.114513      0.648780   0.740980
# std     38125.819681    2.221968      0.171875      0.180878   0.167783
# min    165853.000000   81.000000      0.000409      0.209000   0.268000
# 25%    211340.000000   82.000000      0.006182      0.543500   0.661000
# 50%    231753.000000   83.500000      0.052000      0.684000   0.784500
# 75%    259223.000000   85.000000      0.150500      0.787000   0.858750
# max    350320.000000   91.000000      0.748000      0.949000   0.974000
#
#        instrumentalness   liveness   loudness  speechiness      tempo  \
# count         50.000000  50.000000  50.000000    50.000000   50.00000
# mean           0.019671   0.183752  -5.862180     0.071138  115.43886
# std            0.106998   0.129598   2.259806     0.055525   25.63526
# ...

# %%
df[['name','artist','length']].sort_values(by='length',ascending=False).head()
# longest songs
# Out:
#                name     artist  length
# 43         Superman     Eminem  350320
# 1     The Scientist   Coldplay  309600
# 24  Till I Collapse     Eminem  297786
# 35          Fix You   Coldplay  295533
# 33      Bad Romance  Lady Gaga  294573

# %%
df[['name','artist','popularity']].sort_values(by='popularity',ascending=False).head()
# most popular songs
# Out:
#                                  name               artist  popularity
# 0                    I Wanna Be Yours       Arctic Monkeys          91
# 6                              Yellow             Coldplay          89
# 2                           Unwritten  Natasha Bedingfield          88
# 3                          Without Me               Eminem          88
# 4  Hips Don't Lie (feat. Wyclef Jean)              Shakira          87

# %%
df[['name','artist','acousticness']].sort_values(by='acousticness',ascending=False).head()
# A higher acousticness value indicates the song is more likely to feature acoustic instruments 
# and lack electronic elements, while a lower value suggests a more electronic or amplified sound.
# Out:
#                   name        artist  acousticness
# 22              Sparks      Coldplay         0.748
# 1        The Scientist      Coldplay         0.731
# 41  If I Ain't Got You   Alicia Keys         0.603
# 18          Smack That          Akon         0.323
# 30            Gasolina  Daddy Yankee         0.322

# %%
df[['name','artist','danceability']].sort_values(by='danceability',ascending=False).head()
# describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, 
# beat strength, and overall regularity
# Out:
#                                 name    artist  danceability
# 13               The Real Slim Shady    Eminem         0.949
# 18                        Smack That      Akon         0.939
# 46                Low (feat. T-Pain)  Flo Rida         0.918
# 3                         Without Me    Eminem         0.908
# 14  Yeah! (feat. Lil Jon & Ludacris)     USHER         0.894

# %%
df[['name','artist','energy']].sort_values(by='energy',ascending=False).head()
# most energizing songs
# energetic tracks feel fast, loud, and noisy
# Out:
#                 name                 artist  energy
# 25           Hey Ya!                Outkast   0.974
# 28       Promiscuous          Nelly Furtado   0.970
# 27  Bring Me To Life            Evanescence   0.943
# 20        Can't Stop  Red Hot Chili Peppers   0.938
# 33       Bad Romance              Lady Gaga   0.921

# %%
df[['name','artist','instrumentalness']].sort_values(by='instrumentalness',ascending=False).head()
# The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content
# only song 39 can be considered highly instrumental
# Out:
#                  name             artist  instrumentalness
# 39      The Way I Are          Timbaland            0.7500
# 10  Seven Nation Army  The White Stripes            0.1180
# 22             Sparks           Coldplay            0.0517
# 17              Toxic     Britney Spears            0.0250
# 0    I Wanna Be Yours     Arctic Monkeys            0.0220

# %%
df[['name','artist','liveness']].sort_values(by='liveness',ascending=False).head()
# Detects the presence of an audience in the recording
# Higher liveness values represent an increased probability that the track was performed live.
# Out:
#                                   name           artist  liveness
# 15                      Feel Good Inc.         Gorillaz     0.613
# 49                     I Gotta Feeling  Black Eyed Peas     0.509
# 16                                Numb      Linkin Park     0.484
# 4   Hips Don't Lie (feat. Wyclef Jean)          Shakira     0.405
# 26                     Flashing Lights       Kanye West     0.386

# %%
df[['name','artist','loudness']].sort_values(by='loudness',ascending=True).head()
# The overall loudness of a track in decibels (dB)
# lowest songs
# Out:
#                   name          artist  loudness
# 36       Back To Black   Amy Winehouse   -13.964
# 22              Sparks        Coldplay   -10.506
# 47               Duvet             bôa    -9.414
# 0     I Wanna Be Yours  Arctic Monkeys    -9.345
# 41  If I Ain't Got You     Alicia Keys    -9.129

# %%
df[['name','artist','loudness']].sort_values(by='loudness',ascending=False).head()
# loudest songs
# Out:
#                         name         artist  loudness
# 25                   Hey Ya!        Outkast    -2.261
# 23                   TiK ToK          Kesha    -2.718
# 3                 Without Me         Eminem    -2.827
# 43                  Superman         Eminem    -3.138
# 44  You're Gonna Go Far, Kid  The Offspring    -3.159

# %%
df[['name','artist','speechiness']].sort_values(by='speechiness',ascending=True).head()
# Speechiness detects the presence of spoken words in a track. 
# The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. 
# Values below 0.33 most likely represent music and other non-speech-like tracks.
# Out:
#                           name           artist  speechiness
# 1                The Scientist         Coldplay       0.0243
# 0             I Wanna Be Yours   Arctic Monkeys       0.0256
# 49             I Gotta Feeling  Black Eyed Peas       0.0265
# 48  Drops of Jupiter (Tell Me)            Train       0.0276
# 6                       Yellow         Coldplay       0.0281

# %%
df[['name','artist','speechiness']].sort_values(by='speechiness',ascending=False).head()
# Out:
#                name    artist  speechiness
# 31      Ms. Jackson   Outkast        0.269
# 8       Mockingbird    Eminem        0.266
# 24  Till I Collapse    Eminem        0.186
# 15   Feel Good Inc.  Gorillaz        0.177
# 23          TiK ToK     Kesha        0.142

# %%
df[['name','artist','tempo']].sort_values(by='tempo',ascending=False).head()
# The overall estimated tempo of a track in beats per minute (BPM). 
# In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
# Out:
#                  name           artist    tempo
# 6              Yellow         Coldplay  173.372
# 12  How You Remind Me       Nickelback  172.094
# 24    Till I Collapse           Eminem  171.447
# 34         The Middle  Jimmy Eat World  162.152
# 19        Sex on Fire    Kings of Leon  153.398

# %%
df[['name','artist','time_signature']].sort_values(by='time_signature',ascending=False).head()
# An estimated time signature. The time signature (meter) is a notational convention to specify 
# how many beats are in each bar (or measure).
# Out:
#                         name               artist  time_signature
# 0           I Wanna Be Yours       Arctic Monkeys               4
# 1              The Scientist             Coldplay               4
# 27          Bring Me To Life          Evanescence               4
# 28               Promiscuous        Nelly Furtado               4
# 29  Murder On The Dancefloor  Sophie Ellis-Bextor               4
